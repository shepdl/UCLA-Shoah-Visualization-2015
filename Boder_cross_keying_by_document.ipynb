# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Boder_indexs_1_subjects_situations.csv")
df2 = pd.read_csv("Boder_indexs_2_geographical_ethic.csv")
df3 = pd.read_csv("Boder_indexs_3_persons_organizations.csv")

# %%
df1
# Out:
#                           word  \
# 0                    Accidents
# 1                  Accusations
# 2                    “Actions”
# 3                       Actors
# 4                  Adolescents
# 5                   Affidavits
# 6                  Agronomists
# 7                       Agudah
# 8                Air Pollution
# 9                    Air raids
# 10                 Anesthetics
# 11                   Anschluss
# 12               Anti-Semitism
# 13                     Appells
# 14                      Armies
# 15                      Armies
# 16                  Architects
# 17   “Aryans” & “Aryan” papers
# 18                    Assembly
# 19                      Asylum
# 20                       Basow
# 21                     Bathing
# 22                       Berig
# 23                       Bible
# 24                   Blackmail
# 25                Black Market
# 26          B’nai B’rith Lodge
# 27                  Bolsheviks
# 28                       Books
# ...

# %%
df2
# Out:
#                   word                                        note  \
# 0             Allerich                                     ['(?)']
# 1           Alma - Ata  ['(formerly Vernyi)', 'misspelled Almata']
# 2           Altengrube                                         NaN
# 3            Americans                                         NaN
# 4              Ampfing                                     ['(?)']
# 5            Andrychow                                         NaN
# 6            Antolowka                         ['(see Antonowka)']
# 7            Antonowka                                         NaN
# 8              Antwerp                                         NaN
# 9                Arabs                                         NaN
# 10           Argentina                                         NaN
# 11   Ariege Department                                  ['France']
# 12       Aschaffenburg                                         NaN
# ...

# %%
df3
# Out:
#                            word  has_full  word_full  \
# 0                        Altoff         1        NaN
# 1                        Anders         1        NaN
# 2                     Ansbacher         1        NaN
# 3                     Augustine         1        NaN
# 4                           Bar         2        NaN
# 5                         Baron         1        NaN
# 6                    Bassfreund         2        NaN
# 7                Battenschlager         1        NaN
# 8                          Beck         2        NaN
# 9                         Bevin         1        NaN
# 10                       Biebow         1        NaN
# 11                       Bielka         2        NaN
# 12                       Binder         2        NaN
# 13                     Birnbaum         1        NaN
# 14                         Biro         1        NaN
# 15                    Bisenhaus         2        NaN
# 16            Bloch Rabbi Meyer         2        NaN
# ...

# %%
# exclue nans num
df1 = df1[pd.notnull(df1['num'])]
df2 = df2[pd.notnull(df2['num'])]
df3 = df3[pd.notnull(df3['num'])]

# %%
# check data type in the lists
df1.num[0][0] # should change to list of intergers
# Out:
# '['

# %%
import ast

# %%
x = u'[11,22,33,44]'

# %%
x = '[11,22,33,44]'.lstrip('u')

# %%
x = ast.literal_eval(x)

# %%
x
# Out:
# [11, 22, 33, 44]

# %%
x[0]
# Out:
# 11

# %%
type(x[0])
# Out:
# int

# %%
# change num to lists of intergers
df1.num = df1.num.apply(lambda x: ast.literal_eval(x.lstrip('u')))
df2.num = df2.num.apply(lambda x: ast.literal_eval(x.lstrip('u')))
df3.num = df3.num.apply(lambda x: ast.literal_eval(x.lstrip('u')))
# Out:
# /Users/lizhoufan/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df1
# Out:
#                           word  \
# 0                    Accidents
# 1                  Accusations
# 3                       Actors
# 4                  Adolescents
# 5                   Affidavits
# 6                  Agronomists
# 7                       Agudah
# 8                Air Pollution
# 9                    Air raids
# 10                 Anesthetics
# 11                   Anschluss
# 12               Anti-Semitism
# 13                     Appells
# 15                      Armies
# 16                  Architects
# 17   “Aryans” & “Aryan” papers
# 18                    Assembly
# 19                      Asylum
# 20                       Basow
# 21                     Bathing
# 22                       Berig
# 23                       Bible
# 25                Black Market
# 26          B’nai B’rith Lodge
# 27                  Bolsheviks
# 28                       Books
# 29                      Brawls
# 30                     Bribery
# 31                  Broadcasts
# ...
